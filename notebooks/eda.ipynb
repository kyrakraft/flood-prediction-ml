# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

#Set paths for importing data
project_root = os.path.abspath(os.path.join(os.getcwd(), "..")) #set root to main project dir
data_path = os.path.join(project_root, 'data') #path to data folder

#Load data
train = pd.read_csv(os.path.join(data_path, 'train.csv'))
test = pd.read_csv(os.path.join(data_path, 'test.csv'))

train = train.drop('id', axis=1) 

#Basic info

print("Train shape:", train.shape)
print("Test shape:", test.shape)
print("\nMissing values:\n", train.isnull().sum())

train.head()
# Out:
# Train shape: (1117957, 21)
# Test shape: (745305, 21)
#
# Missing values:
#  MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# FloodProbability                   0
# dtype: int64
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# ...

# %%
train.describe().T
# Out:
#                                      count      mean       std    min   25%  \
# MonsoonIntensity                 1117957.0  4.921450  2.056387  0.000  3.00
# TopographyDrainage               1117957.0  4.926671  2.093879  0.000  3.00
# RiverManagement                  1117957.0  4.955322  2.072186  0.000  4.00
# Deforestation                    1117957.0  4.942240  2.051689  0.000  4.00
# Urbanization                     1117957.0  4.942517  2.083391  0.000  3.00
# ClimateChange                    1117957.0  4.934093  2.057742  0.000  3.00
# DamsQuality                      1117957.0  4.955878  2.083063  0.000  4.00
# Siltation                        1117957.0  4.927791  2.065992  0.000  3.00
# AgriculturalPractices            1117957.0  4.942619  2.068545  0.000  3.00
# Encroachments                    1117957.0  4.949230  2.083324  0.000  4.00
# IneffectiveDisasterPreparedness  1117957.0  4.945239  2.078141  0.000  3.00
# ...

# %%
#EDA

corr_matrix = train.corr(numeric_only=True) #compute correlation matrix

target_corr = corr_matrix['FloodProbability'].sort_values(ascending=False)
print(target_corr)

#Plot heatmap
plt.figure(figsize=(12,10))
sns.heatmap(corr_matrix, cmap='coolwarm', center=0, annot=False)
plt.title('Feature Correlation Matrix')
plt.show()
# Out:
# FloodProbability                   1.000000
# DeterioratingInfrastructure        0.190007
# MonsoonIntensity                   0.189098
# DamsQuality                        0.187996
# TopographyDrainage                 0.187635
# RiverManagement                    0.187131
# Siltation                          0.186789
# PopulationScore                    0.185890
# Landslides                         0.185346
# ClimateChange                      0.184761
# Deforestation                      0.184001
# WetlandLoss                        0.183396
# AgriculturalPractices              0.183366
# IneffectiveDisasterPreparedness    0.183109
# PoliticalFactors                   0.182417
# Watersheds                         0.181907
# InadequatePlanning                 0.180968
# Urbanization                       0.180861
# DrainageSystems                    0.179305
# Encroachments                      0.178841
# CoastalVulnerability               0.177774
# ...

# %%
sns.clustermap(corr_matrix, cmap='coolwarm', figsize=(12,12))

# %%
train.hist(figsize=(16, 12), bins=30, edgecolor='black')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.histplot(train['FloodProbability'], kde=True, bins=50)
plt.title("Distribution of FloodProbability")
plt.show()

# %%
import xgboost as xgb
X = train.drop(columns='FloodProbability')
y = train['FloodProbability']

model = xgb.XGBRegressor(n_estimators=50, max_depth=4, random_state=42)
model.fit(X, y)

xgb.plot_importance(model, importance_type='gain', max_num_features=30, title='Feature Importance (by Gain)')
plt.tight_layout()
plt.show()

# %%
import xgboost as xgb
X_temp = train.drop(columns='FloodProbability')
X = X_temp
y = train['FloodProbability']

X['sum_of_features'] = X_temp.sum(axis=1)

X['row_mean'] = X_temp.mean(axis=1)
X['row_median'] = X_temp.median(axis=1)
X['row_std'] = X_temp.std(axis=1)
X['row_q25'] = X_temp.quantile(0.25, axis=1)
X['row_q75'] = X_temp.quantile(0.75, axis=1) #don't need bc all have val of 6.00?
X['row_max'] = X_temp.max(axis=1)
X['row_min'] = X_temp.min(axis=1)

model = xgb.XGBRegressor(n_estimators=50, max_depth=4, random_state=42)
model.fit(X, y)

xgb.plot_importance(model, importance_type='gain', max_num_features=50, title='Feature Importance (by Gain)')
plt.tight_layout()
plt.show()

# %%
import xgboost as xgb
X_temp = train.drop(columns='FloodProbability')
X = pd.DataFrame(index=train.index)
y = train['FloodProbability']

X['sum_of_features'] = X_temp.sum(axis=1)

X['row_mean'] = X_temp.mean(axis=1)
X['row_median'] = X_temp.median(axis=1)
X['row_std'] = X_temp.std(axis=1)
X['row_q25'] = X_temp.quantile(0.25, axis=1)
X['row_q75'] = X_temp.quantile(0.75, axis=1) #don't need bc all have val of 6.00?
X['row_max'] = X_temp.max(axis=1)
X['row_min'] = X_temp.min(axis=1)

model = xgb.XGBRegressor(n_estimators=50, max_depth=4, random_state=42)
model.fit(X, y)

xgb.plot_importance(model, importance_type='gain', max_num_features=30, title='Feature Importance (by Gain)')
plt.tight_layout()
plt.show()
